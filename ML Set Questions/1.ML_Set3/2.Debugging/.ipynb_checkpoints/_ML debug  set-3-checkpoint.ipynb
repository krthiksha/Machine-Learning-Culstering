# %%
# !pip install tensorflow

# %%
#1.The following code throws an error. What is wrong?
import tensorflow as tf
model = keras.Sequential()  # Error here

# %%
#2.
from sklearn.svm import SVC
from sklearn.datasets import load_diabetes

X, y = load_diabetes(return_X_y=True)

model = SVC()
model.fit(X,y)  # Error

# y_pred = model.predict(y)
# from sklearn.metrics import confusion_matrix
# cf=confusion_matrix(y,y_pred)
# cf


""" No error"""
# Out:
# ' No error'

# %%
#3.
from sklearn.ensemble import RandomForestClassifier  # Incorrect import
clf = RandomForestClassifier()
clf

""" library for random forest => from sklearn.ensemble """
# Out:
# ' library for random forest => from sklearn.ensemble '

# %%
#4.
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = [[1, 2], [3, 4], [5, 6], [7, 8]]
y = [0, 1, 0, 1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)  # Error

print(X_train, X_test)


""" as we calculate mean & stddev using fit_transform in x_train, no need to calculate it again. Just use transform() for x_test"""
# Out:
# [[-1. -1.]
#  [ 1.  1.]] [[0. 0.]
#  [2. 2.]]
# ' as we calculate mean & stddev using fit_transform in x_train, no need to calculate it again. Just use transform() for x_test'

# %%
#5.
import pandas as pd
df = pd.DataFrame({'age': [25, 30, 35], 'salary': [50000, 60000, 70000]})
print(df['salary'])  # Typo

""" salry -- misspelled"""
# Out:
# 0    50000
# 1    60000
# 2    70000
# Name: salary, dtype: int64
# ' salry -- misspelled'

# %%
#6.import pandas as pd
df = pd.DataFrame({'Age': ['25', '30', '35']})  # Stored as string
df['Age'] = [int(i) for i in df['Age']]  # converting as integer
print(df['Age'].mean())
# Out:
# 30.0

# %%
#7.
def add_numbers(a, b):
    result = a + b
    return result

""" indendation error"""
# Out:
# ' indendation error'

# %%
#8.
from sklearn.model_selection import train_test_split
X = [1, 2, 3, 4, 5]
y = [1, 0, 1, 0 ,1]  # Mismatched length
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#9.

my_name = "Alice"  #name defined prior printing it
print(my_name)
# Out:
# Alice

# %%
#10.
import pandas as pd

df = pd.DataFrame({'Age': [25, 30, 35, 40]})
df['Age_Category'] = df['Age'].apply(lambda x: 'Young' if x < 30 else 'Old')  # Error
df['Age_Category']

""" missed 'else' in lambda function """
# Out:
# " missed 'else' in lambda function "
